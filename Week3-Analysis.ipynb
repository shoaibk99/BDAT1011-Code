# %% [markdown]
# # First we will convert the .xlsx file into .csv

# %%
import pandas as pd 
read_file = pd.read_excel ("Coffee_Shop_Sales_Dataset_012124.xlsx") 

read_file.to_csv("Coffee_Shop_Sales_Dataset.csv", index = None, header=True)

df = pd.DataFrame(pd.read_csv("Coffee_Shop_Sales_Dataset.csv")) 

# show the dataframe 
df
# Out:
#         Transaction ID Transaction Date Transaction Time  \
# 0                    1       2023-01-01         07:06:11
# 1                    2       2023-01-01         07:08:56
# 2                    3       2023-01-01         07:14:04
# 3                    4       2023-01-01         07:20:24
# 4                    5       2023-01-01         07:22:41
# ...                ...              ...              ...
# 149982          149436       2023-06-30         19:44:46
# 149983          149437       2023-06-30         19:44:46
# 149984          149438       2023-06-30         19:45:16
# 149985          149439       2023-06-30         19:45:52
# 149986          149440       2023-06-30         19:46:02
#
#         Transaction Quantity  Store ID   Store Location  Product ID  \
# 0                          2       5.0  Lower Manhattan          32
# 1                          2       5.0  Lower Manhattan          57
# 2                          2       5.0  Lower Manhattan          59
# 3                          1       5.0  Lower Manhattan          22
# 4                          2       5.0  Lower Manhattan          57
# ...                      ...       ...              ...         ...
# 149982                     1       3.0          Astoria          60
# 149983                     2       3.0          Astoria          72
# 149984                     1       3.0          Astoria          41
# 149985                     1       3.0          Astoria          46
# 149986                     2       8.0   Hell's Kitchen          55
#
#         Unit Price    Product Category           Product Type  \
# 0             3.00              Coffee  Gourmet brewed coffee
# 1             3.10                 Tea        Brewed Chai tea
# 2             4.50  Drinking Chocolate          Hot chocolate
# 3             2.00              Coffee            Drip coffee
# 4             3.10                 Tea        Brewed Chai tea
# ...            ...                 ...                    ...
# 149982        3.75  Drinking Chocolate          Hot chocolate
# 149983        3.25              Bakery                  Scone
# 149984        4.25              Coffee       Barista Espresso
# 149985        2.50                 Tea       Brewed Green tea
# 149986        4.00                 Tea        Brewed Chai tea
#
#                       Product Detail
# 0                        Ethiopia Rg
# 1           Spicy Eye Opener Chai Lg
# 2                  Dark chocolate Lg
# 3        Our Old Time Diner Blend Sm
# 4           Spicy Eye Opener Chai Lg
# ...                              ...
# 149982  Sustainably Grown Organic Rg
# 149983                  Ginger Scone
# 149984                 Cappuccino Lg
# 149985         Serenity Green Tea Rg
# 149986       Morning Sunrise Chai Lg
#
# [149987 rows x 11 columns]

# %% [markdown]
# # Cleaning null values

# %%
df.dropna(subset=["Store Location", "Store ID"], inplace=True)
df.to_csv("Coffee_Shop_Sales_Dataset.csv", index=False)

# %% [markdown]
# # Removing the seconds from the time in "Transaction Time" column

# %%
df['Transaction Time'] = pd.to_datetime(df['Transaction Time'], format='%H:%M:%S')
df['Transaction Time'] = df['Transaction Time'].dt.strftime('%H:%M')
df.to_csv("Coffee_Shop_Sales_Dataset.csv", index=False)

# %% [markdown]
# # Removing duplicates

# %%
df = df.drop_duplicates(subset="Transaction ID", keep=False)
df.tail(20)
# Out:
#         Transaction ID Transaction Date Transaction Time  \
# 148225          148566       2023-06-30            08:17
# 148226          148567       2023-06-30            08:17
# 148227          148568       2023-06-30            08:17
# 148228          148569       2023-06-30            08:17
# 149100          149441       2023-06-30            19:46
# 149101          149442       2023-06-30            19:46
# 149102          149443       2023-06-30            19:46
# 149103          149444       2023-06-30            19:51
# 149104          149445       2023-06-30            19:52
# 149105          149446       2023-06-30            19:53
# 149106          149447       2023-06-30            19:56
# 149107          149448       2023-06-30            19:57
# 149108          149449       2023-06-30            19:57
# 149109          149450       2023-06-30            20:08
# 149110          149451       2023-06-30            20:16
# 149111          149452       2023-06-30            20:18
# 149112          149453       2023-06-30            20:25
# 149113          149454       2023-06-30            20:31
# 149114          149455       2023-06-30            20:57
# 149115          149456       2023-06-30            20:57
#
#         Transaction Quantity  Store ID   Store Location  Product ID  \
# 148225                     2       8.0   Hell's Kitchen          63
# 148226                     1       8.0   Hell's Kitchen          38
# 148227                     2       8.0   Hell's Kitchen          64
# 148228                     1       3.0          Astoria          30
# 149100                     1       8.0   Hell's Kitchen          27
# 149101                     1       8.0   Hell's Kitchen          75
# 149102                     2       3.0          Astoria          50
# 149103                     2       3.0          Astoria          26
# 149104                     2       3.0          Astoria          34
# 149105                     1       3.0          Astoria          24
# 149106                     1       8.0   Hell's Kitchen          33
# 149107                     2       3.0          Astoria          54
# 149108                     1       3.0          Astoria          70
# 149109                     2       8.0   Hell's Kitchen          55
# 149110                     2       5.0  Lower Manhattan          42
# 149111                     2       8.0   Hell's Kitchen          44
# 149112                     2       8.0   Hell's Kitchen          49
# 149113                     1       8.0   Hell's Kitchen          45
# 149114                     1       8.0   Hell's Kitchen          40
# 149115                     2       8.0   Hell's Kitchen          64
#
#         Unit Price Product Category           Product Type  \
# 148225        0.80         Flavours          Regular syrup
# 148226        3.75           Coffee       Barista Espresso
# 148227        0.80         Flavours          Regular syrup
# 148228        3.00           Coffee  Gourmet brewed coffee
# 149100        3.50           Coffee  Organic brewed coffee
# 149101        3.50           Bakery                Pastry+
# 149102        2.50              Tea       Brewed Black tea
# 149103        3.00           Coffee  Organic brewed coffee
# 149104        2.45           Coffee  Premium brewed coffee
# 149105        3.00           Coffee            Drip coffee
# 149106        3.50           Coffee  Gourmet brewed coffee
# 149107        2.50              Tea        Brewed Chai tea
# 149108        3.25           Bakery                  Scone
# 149109        4.00              Tea        Brewed Chai tea
# 149110        2.50              Tea      Brewed herbal tea
# 149111        2.50              Tea      Brewed herbal tea
# 149112        3.00              Tea       Brewed Black tea
# 149113        3.00              Tea      Brewed herbal tea
# 149114        3.75           Coffee       Barista Espresso
# 149115        0.80         Flavours          Regular syrup
#
#                      Product Detail
# 148225                 Carmel syrup
# 148226                        Latte
# 148227               Hazelnut syrup
# 148228    Columbian Medium Roast Lg
# 149100                 Brazilian Lg
# 149101                    Croissant
# 149102                 Earl Grey Rg
# 149103                 Brazilian Rg
# 149104     Jamaican Coffee River Sm
# 149105  Our Old Time Diner Blend Lg
# 149106                  Ethiopia Lg
# 149107      Morning Sunrise Chai Rg
# 149108              Cranberry Scone
# 149109      Morning Sunrise Chai Lg
# 149110               Lemon Grass Rg
# 149111                Peppermint Rg
# 149112         English Breakfast Lg
# 149113                Peppermint Lg
# 149114                   Cappuccino
# 149115               Hazelnut syrup

# %%
df.to_csv("Coffee_Shop_Sales_Dataset.csv", index=False)

# %% [markdown]
# # Rearranging the dataset

# %%
desired_columns_order = ["Transaction ID", "Transaction Date","Transaction Time", "Store ID","Store Location", "Product ID", "Unit Price", "Transaction Quantity", "Product Category", "Product Type", "Product Detail"]
df = df[desired_columns_order]
df.head(20)
# Out:
#     Transaction ID Transaction Date Transaction Time  Store ID  \
# 0                1       2023-01-01            07:06       5.0
# 1                2       2023-01-01            07:08       5.0
# 2                3       2023-01-01            07:14       5.0
# 3                4       2023-01-01            07:20       5.0
# 4                5       2023-01-01            07:22       5.0
# 5                6       2023-01-01            07:22       5.0
# 6                7       2023-01-01            07:25       5.0
# 7                8       2023-01-01            07:33       5.0
# 8                9       2023-01-01            07:39       5.0
# 9               10       2023-01-01            07:39       5.0
# 10              11       2023-01-01            07:43       5.0
# 11              12       2023-01-01            07:44       5.0
# 12              13       2023-01-01            07:45       5.0
# 13              14       2023-01-01            07:48       5.0
# 14              15       2023-01-01            07:52       5.0
# 15              16       2023-01-01            07:59       5.0
# 16              17       2023-01-01            07:59       5.0
# 17              18       2023-01-01            08:00       8.0
# 18              19       2023-01-01            08:00       8.0
# 19              20       2023-01-01            08:11       8.0
#
#      Store Location  Product ID  Unit Price  Transaction Quantity  \
# 0   Lower Manhattan          32        3.00                     2
# 1   Lower Manhattan          57        3.10                     2
# 2   Lower Manhattan          59        4.50                     2
# 3   Lower Manhattan          22        2.00                     1
# 4   Lower Manhattan          57        3.10                     2
# 5   Lower Manhattan          77        3.00                     1
# 6   Lower Manhattan          22        2.00                     1
# 7   Lower Manhattan          28        2.00                     2
# 8   Lower Manhattan          39        4.25                     1
# 9   Lower Manhattan          58        3.50                     2
# 10  Lower Manhattan          56        2.55                     1
# 11  Lower Manhattan          33        3.50                     2
# 12  Lower Manhattan          51        3.00                     1
# 13  Lower Manhattan          57        3.10                     1
# 14  Lower Manhattan          87        3.00                     2
# 15  Lower Manhattan          47        3.00                     2
# 16  Lower Manhattan          79        3.75                     1
# 17   Hell's Kitchen          42        2.50                     1
# 18   Hell's Kitchen          59        4.50                     2
# 19   Hell's Kitchen          61        4.75                     1
#
#       Product Category           Product Type                Product Detail
# 0               Coffee  Gourmet brewed coffee                   Ethiopia Rg
# 1                  Tea        Brewed Chai tea      Spicy Eye Opener Chai Lg
# 2   Drinking Chocolate          Hot chocolate             Dark chocolate Lg
# 3               Coffee            Drip coffee   Our Old Time Diner Blend Sm
# 4                  Tea        Brewed Chai tea      Spicy Eye Opener Chai Lg
# 5               Bakery                  Scone                 Oatmeal Scone
# 6               Coffee            Drip coffee   Our Old Time Diner Blend Sm
# 7               Coffee  Gourmet brewed coffee     Columbian Medium Roast Sm
# 8               Coffee       Barista Espresso                      Latte Rg
# 9   Drinking Chocolate          Hot chocolate             Dark chocolate Rg
# 10                 Tea        Brewed Chai tea      Spicy Eye Opener Chai Rg
# 11              Coffee  Gourmet brewed coffee                   Ethiopia Lg
# 12                 Tea       Brewed Black tea                  Earl Grey Lg
# 13                 Tea        Brewed Chai tea      Spicy Eye Opener Chai Lg
# 14              Coffee       Barista Espresso          Ouro Brasileiro shot
# 15                 Tea       Brewed Green tea         Serenity Green Tea Lg
# 16              Bakery                  Scone            Jumbo Savory Scone
# 17                 Tea      Brewed herbal tea                Lemon Grass Rg
# 18  Drinking Chocolate          Hot chocolate             Dark chocolate Lg
# 19  Drinking Chocolate          Hot chocolate  Sustainably Grown Organic Lg

# %%
df.to_csv("Coffee_Shop_Sales_Dataset.csv", index=False)
